# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cause_of_deaths.csv')

# %%
df
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
df.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
df.tail()
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 6115                                      754                  215
# 6116                                      767                  219
# 6117                                      781                  223
# 6118                                      795                  227
# 6119                                      812                  232
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 6115                      3019     2518       770                    1302
# 6116                      3056     2050       801                    1342
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# ...

# %%
len(df)
# Out:
# 6120

# %%
df.shape
# Out:
# (6120, 34)

# %%
df.isnull().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
df['Year'].nunique()
# Out:
# 30

# %%
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df.corr()
# Out:
#                                                 Year  Meningitis  \
# Year                                        1.000000   -0.043288
# Meningitis                                 -0.043288    1.000000
# Alzheimer's Disease and Other Dementias     0.083710    0.216713
# Parkinson's Disease                         0.068756    0.351668
# Nutritional Deficiencies                   -0.078266    0.760851
# Malaria                                    -0.015964    0.755261
# Drowning                                   -0.040910    0.576347
# Interpersonal Violence                     -0.001122    0.447242
# Maternal Disorders                         -0.027460    0.899507
# HIV/AIDS                                    0.022964    0.411881
# Drug Use Disorders                          0.023917    0.187050
# Tuberculosis                               -0.025297    0.844494
# Cardiovascular Diseases                     0.029813    0.411787
# ...

# %%
df.corr()['Year']
# Out:
# Year                                          1.000000
# Meningitis                                   -0.043288
# Alzheimer's Disease and Other Dementias       0.083710
# Parkinson's Disease                           0.068756
# Nutritional Deficiencies                     -0.078266
# Malaria                                      -0.015964
# Drowning                                     -0.040910
# Interpersonal Violence                       -0.001122
# Maternal Disorders                           -0.027460
# HIV/AIDS                                      0.022964
# Drug Use Disorders                            0.023917
# Tuberculosis                                 -0.025297
# Cardiovascular Diseases                       0.029813
# Lower Respiratory Infections                 -0.027531
# Neonatal Disorders                           -0.026949
# Alcohol Use Disorders                         0.011315
# Self-harm                                    -0.004192
# ...

# %%
df.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
df['Country/Territory'].nunique()
# Out:
# 204

# %%
df['Country/Territory'].value_counts()
# Out:
# Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: Country/Territory, Length: 204, dtype: int64

# %%
cause_of_deaths = ['Meningitis','Alzheimer\'s Disease and Other Dementias', 'Parkinson\'s Disease',
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
df['Total_no_of_deaths'] = df[cause_of_deaths].sum(axis=1)

# %%
Top10_Total_no_of_deaths = df.sort_values(by='Total_no_of_deaths', ascending=False)[:10][['Total_no_of_deaths','Country/Territory']]

Top10_Total_no_of_deaths
# Out:
#       Total_no_of_deaths Country/Territory
# 1139            10442561             China
# 1138            10163943             China
# 1137             9978653             China
# 1119             9814213             China
# 1118             9591222             China
# 1117             9503904             China
# 1116             9411928             China
# 1114             9366974             China
# 1115             9364587             China
# 1113             9284664             China

# %%
India_Total_no_of_deaths_df = df[df['Country/Territory']=='India'].sort_values(by='Total_no_of_deaths',ascending=False)

# %%
#India - "total_no_of_Deaths" against "Year"


plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(data=India_Total_no_of_deaths_df, x='Year',y='Total_no_of_deaths')
plt.xlabel("Year")
plt.ylabel("Total no.of deaths")
plt.title("Year Vs.Total no.of deaths for India")
plt.show();

# %%
plt.figure(figsize=(15,8),dpi=200)
sns.barplot(data=India_Total_no_of_deaths_df, x='Year',y='Total_no_of_deaths')
plt.xlabel("Year")
plt.ylabel("Total no.of deaths")
plt.title("Year Vs.Total no. of deaths for India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Malaria'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Malaria deaths")
plt.title("Year Vs.Malaria deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Meningitis'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Meningitis deaths")
plt.title("Year Vs. Meningitis deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Alzheimer\'s Disease and Other Dementias'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Alzheimer\'s Disease and Other Dementias deaths")
plt.title("Year Vs.Alzheimer\'s Disease and Other Dementias deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Parkinson\'s Disease'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Parkinson\'s Disease deaths")
plt.title("Year Vs.Parkinson\'s Disease deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Nutritional Deficiencies'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Nutritional Deficiencies deaths")
plt.title("Year Vs.Nutritional Deficiencies deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Drowning'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Drowning deaths")
plt.title("Year Vs.Drowning deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Interpersonal Violence'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Interpersonal Violence deaths")
plt.title("Year Vs.Interpersonal Violence deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Maternal Disorders'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Maternal Disorders deaths")
plt.title("Year Vs.Maternal Disorders deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Drug Use Disorders'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Drug Use Disorders deaths")
plt.title("Year Vs.Drug Use Disorders deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Tuberculosis'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Tuberculosis deaths")
plt.title("Year Vs.Tuberculosis deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Cardiovascular Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Cardiovascular Diseases deaths")
plt.title("Year Vs.Cardiovascular Diseases deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Lower Respiratory Infections'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Lower Respiratory Infections deaths")
plt.title("Year Vs.Lower Respiratory Infections deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Neonatal Disorders'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Neonatal Disorders deaths")
plt.title("Year Vs.Neonatal Disorders deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Alcohol Use Disorders'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Alcohol Use Disorders deaths")
plt.title("Year Vs.Alcohol Use Disorders deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Self-harm'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Self-harm deaths")
plt.title("Year Vs.Self-harm deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Exposure to Forces of Nature'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Exposure to Forces of Nature deaths")
plt.title("Year Vs.Exposure to Forces of Nature deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Diarrheal Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Diarrheal Diseases deaths")
plt.title("Year Vs.Diarrheal Diseases deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Environmental Heat and Cold Exposure'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Enviromental Heat and Cold Exposure deaths")
plt.title("Year Vs.Enviromental Heat and Cold Exposure deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Neoplasms'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Neoplasms deaths")
plt.title("Year Vs.Neoplasms deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Conflict and Terrorism'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Conflict and Terrorism deaths")
plt.title("Year Vs.Conflict and Terrorism deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Diabetes Mellitus'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Diabetes Mellitus deaths")
plt.title("Year Vs.Diabetes Mellitus deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Chronic Kidney Disease'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("chronic kidney Disease deaths")
plt.title("Year Vs.Chronic Kidney Disease deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Poisonings'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Poisonings deaths")
plt.title("Year Vs.Poisonings deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Protein-Energy Malnutrition'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Protein-Energy Malnutrition deaths")
plt.title("Year Vs.Protein-Energy Malnutrition deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Chronic Respiratory Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Chronic Respiratory Diseases deaths")
plt.title("Year Vs.Chronic Respiratory Diseases deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Cirrhosis and Other Chronic Liver Diseases' ].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Cirrhosis and Other Chronic Liver Diseases deaths")
plt.title("Year Vs.Cirrhosis and Other Chronic Liver Diseases deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Digestive Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Digestive Diseases deaths")
plt.title("Year Vs.Digestive Diseases deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Fire, Heat, and Hot Substances'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Fire, Heat, and Hot Substances deaths")
plt.title("Year Vs.Fire, Heat, and Hot Substance deaths in India")
plt.show();

# %%
plt.figure(figsize=(12,8),dpi=200)
India_df = India_Total_no_of_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Acute Hepatitis'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Acute Hepatitis deaths")
plt.title("Year Vs.Acute Hepatitis deaths in India")
plt.show();

# %%
Countries_Total_no_of_deaths_noyear_df = df.groupby('Country/Territory').sum()
Countries_Total_no_of_deaths_noyear_df.drop('Year',axis=1,inplace=True)

# %%
Total_no_of_deaths_noyear_df.sort_values(by='Total_no_of_deaths',ascending =False)[1:2]
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# India                 2008944                                  1707561
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# India                           756832                   3290569  2439244
#
#                    Drowning  Interpersonal Violence  Maternal Disorders  \
# Country/Territory
# India               2110438                 1237163             2292449
#
#                    HIV/AIDS  Drug Use Disorders  ...  Chronic Kidney Disease  \
# Country/Territory                                ...
# India               2454374              168928  ...                 4556172
#
#                    Poisonings  Protein-Energy Malnutrition  Road Injuries  \
# Country/Territory
# India                  170119                      2356222        5346154
#
#                    Chronic Respiratory Diseases  \
# Country/Territory
# ...

# %%
IndiaTop10 = Total_no_of_deaths_noyear_df.sort_values(by='Total_no_of_deaths',ascending =False)[1:2]

# %%
IndiaTop10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       52994710
# Diarrheal Diseases                            26243547
# Chronic Respiratory Diseases                  25232974
# Neonatal Disorders                            20911570
# Neoplasms                                     17762703
# Lower Respiratory Infections                  16419404
# Tuberculosis                                  15820922
# Digestive Diseases                            11804380
# Cirrhosis and Other Chronic Liver Diseases     6294910
# Self-harm                                      5543395
# Name: India, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
IndiaTop10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in India")
plt.show();
